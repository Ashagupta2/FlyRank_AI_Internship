# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashagupta2/FlyRank_AI_Internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Ashagupta2/FlyRank_AI_Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My Lane
#
# I chose the **Content Refresh Prioritization** lane.
#
# Many websites have thousands of pages, but only a limited amount of time to update them. Instead of refreshing every page, I want to identify pages that are most likely to benefit from a content refresh.
#
# This lane is useful because it helps SEO teams decide which pages should be updated first. The goal is not to replace human judgment but to support better prioritization using historical page data.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## Research Question
#
# **Decision:** Which pages should be prioritized for content refresh?
#
# **Who takes the action?**
# SEO managers or content teams.
#
# **Action:**
# Update the selected pages by improving content, metadata, or keyword targeting.
#
# **Cost of a wrong recommendation:**
# If a page is incorrectly prioritized, the team may spend time updating a page that brings little benefit while ignoring pages with higher potential. This wastes resources and may reduce overall traffic growth.
#
# **Why ML can help:**
# The dataset contains historical information such as impressions, clicks, CTR, content length, and search volume. These patterns may help rank pages based on their likelihood of benefiting from a refresh.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ## Quick look at the data
#
# I loaded the starter dataset to understand whether the Content Refresh Prioritization lane is worth exploring.
#
# The dataset contains many pages along with metrics such as impressions, clicks, CTR, and search volume. I examined a few summary statistics to understand the size of the dataset and the variation in page performance.
#
# These numbers suggest that pages perform differently, making it reasonable to investigate which pages should be prioritized for a content refresh.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

print("Number of pages:", len(df))
print("Average CTR:", round(df["ctr_90d"].mean(), 4))
print("Median search volume:", df["search_volume"].median())
print("Pages with impressions > 100:",
      (df["impressions_90d"] > 100).sum())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1754/1916222513.py in <cell line: 0>()
#       3 import pandas as pd
#       4
# ----> 5 df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")
#       6
#       7 print("Number of pages:", len(df))
#
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## What I can and cannot claim
#
# This project can provide decision-support by identifying pages that appear more suitable for a content refresh based on historical data.
#
# The results should be interpreted as observed patterns rather than facts.
#
# This project cannot prove that refreshing a page will increase traffic, nor can it predict Google's ranking algorithm. Any recommendations should be combined with human review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
